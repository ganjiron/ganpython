# %%
import pandas as pd
from scipy.spatial.distance import cosine
import numpy as np
from scipy.sparse import csr_matrix
from __future__ import division
import matplotlib.pyplot as plt
from scipy import fft, arange, signal
# %matplotlib inline

# %%
train_data = pd.read_csv("train_data.csv")
test_data = pd.read_csv("test_data.csv")

# %%
train_data["type_1"] = train_data["user_id"].map(str) +"_"+ train_data["action_id"]

# %%
train_data
# Out:
#          attitude.roll  attitude.pitch  attitude.yaw  gravity.x  gravity.y  \
# 0             1.528132       -0.733896      0.696372   0.741895   0.669768
# 1             1.527992       -0.716987      0.677762   0.753099   0.657116
# 2             1.527765       -0.706999      0.670951   0.759611   0.649555
# 3             1.516768       -0.704678      0.675735   0.760709   0.647788
# 4             1.493941       -0.703918      0.672994   0.760062   0.647210
# 5             1.476302       -0.700807      0.669443   0.760912   0.644835
# 6             1.455153       -0.694408      0.662593   0.763300   0.639930
# 7             1.441702       -0.690710      0.656459   0.764380   0.637084
# 8             1.443440       -0.691905      0.651196   0.763796   0.638005
# 9             1.443071       -0.693039      0.638198   0.763042   0.638878
# 10            1.434186       -0.693527      0.616938   0.761832   0.639253
# ...

# %%
motion_type = set(train_data["type_1"])
len(motion_type)
# Out:
# 315

# %%
x_train = train_data.drop(["action_id"] , axis = 1)
x_test = test_data.drop(["action_id"], axis = 1)

# %%
y_train = train_data["action_id"].apply(lambda x:x[:3])
y_test= test_data["action_id"].apply(lambda x:x[:3])
