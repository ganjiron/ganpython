# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import statsmodels.formula.api as smf
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
creditcard = pd.read_csv("creditcard.csv")
creditcard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %%
creditcard.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %%
creditcard.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
# creditcard.drop(['V23'] , axis=1)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
counts = creditcard['Class'].value_counts(normalize = True)

# %%
counts
# Out:
# 0    0.998273
# 1    0.001727
# Name: Class, dtype: float64

# %%
creditcard.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
g = creditcard.groupby('Class')

# %%
g.describe()
# Out:
#          Amount                                                              \
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.291022  250.105092  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.211321  256.683288  0.0  1.00   9.25  105.89   2125.87
#
#            Time                  ...            V8                   V9  \
#           count          mean    ...           75%        max     count
# Class                            ...
# 0      284315.0  94838.202258    ...      0.326200  18.709255  284315.0
# 1         492.0  80746.806911    ...      1.764879  20.007208     492.0
#
#
#            mean       std        min       25%       50%      75%        max
# Class
# 0      0.004467  1.089372  -6.290730 -0.640412 -0.049964  0.59823  15.594995
# 1     -2.581123  2.500896 -13.434066 -3.872383 -2.208768 -0.78785   3.353525
#
# [2 rows x 240 columns]

# %%
gd = creditcard.iloc[:].groupby('Class')
gd.describe()
# Out:
#          Amount                                                              \
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.291022  250.105092  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.211321  256.683288  0.0  1.00   9.25  105.89   2125.87
#
#            Time                  ...            V8                   V9  \
#           count          mean    ...           75%        max     count
# Class                            ...
# 0      284315.0  94838.202258    ...      0.326200  18.709255  284315.0
# 1         492.0  80746.806911    ...      1.764879  20.007208     492.0
#
#
#            mean       std        min       25%       50%      75%        max
# Class
# 0      0.004467  1.089372  -6.290730 -0.640412 -0.049964  0.59823  15.594995
# 1     -2.581123  2.500896 -13.434066 -3.872383 -2.208768 -0.78785   3.353525
#
# [2 rows x 240 columns]

# %%
creditcard.columns.size
# Out:
# 31

# %%
cd = creditcard

# %%
d1 = cd[creditcard.columns[1]][creditcard.Class == 1]
d2 = cd[creditcard.columns[1]][creditcard.Class == 0]

# %%
sns.distplot(d1, color="b")
sns.distplot(d2, color="r")
plt.show()

# %%
pos = [131,132,133]
for i in range(1,creditcard.columns.size-2):
    plot_lm_1 = plt.figure((i-1)//3)
    plt.subplot(pos[(i-1)%3])
    plot_lm_1.set_figheight(4)
    plot_lm_1.set_figwidth(15)
    d1 = cd[creditcard.columns[i]][creditcard.Class == 1]
    d2 = cd[creditcard.columns[i]][creditcard.Class == 0]    
    sns.distplot(d1, color="b")
    sns.distplot(d2, color="r")
plt.show()

# %%
pos = [141,142,143,144]
# for i in range(1,creditcard.columns.size):
for i in range(1,4):
    plot_lm_1 = plt.figure(i)
    plot_lm_1.set_figheight(4)
    plot_lm_1.set_figwidth(15)
    d1 = cd[creditcard.columns[i]][creditcard.Class == 1]
    d2 = cd[creditcard.columns[i]][creditcard.Class == 0]
    plt.subplot(pos[0])
    sns.distplot(d1, color="b")
    sns.distplot(d2, color="r")
    
    plt.subplot(pos[1])
    plt.plot(d2 , 'r*' )
    plt.plot(d1 , 'bo' ) 
    
    
    plt.subplot(pos[2])
#     sns.categorical(x="Time", y="V1", data=creditcard);
#     sns.pairplot(creditcard, hue="Class")
    
    
#     plt.bar(cd[creditcard.columns[0]][creditcard.Class == 1] , d1, width=0.3 , bottom=5)
#     plt.bar(cd[creditcard.columns[0]][creditcard.Class == 0] , d2, width=0.3 , bottom=5)
plt.show()

# %%
gd[gd['Class'] == 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-1d5ceec8dbd0> in <module>()
# ----> 1 gd[gd['Class'] == 0]
#
# C:\Program Files\Anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     352         else:
#     353             if key not in self.obj:
# --> 354                 raise KeyError("Column not found: %s" % key)
#     355             return self._gotitem(key, ndim=1)
#     356
#
# KeyError: 'Column not found: False'

# %%
plt.plot(creditcard.V1 )

# %%
plt.scatter(creditcard['V2'] , creditcard['V3'] , s = 0.1 , alpha=0.03)

# %%
plt.hist(creditcard['V2'])
# Out:
# (array([2.00000e+00, 1.00000e+00, 5.00000e+00, 1.70000e+01, 4.60000e+01,
#         1.77000e+02, 1.46300e+03, 2.78631e+05, 4.42700e+03, 3.80000e+01]),
#  array([-72.71572756, -63.23838191, -53.76103625, -44.2836906 ,
#         -34.80634494, -25.32899929, -15.85165363,  -6.37430798,
#           3.10303768,  12.58038334,  22.05772899]),
#  <a list of 10 Patch objects>)

# %%
creditcard[['V1', 'V2']].corr()
# Out:
#               V1            V2
# V1  1.000000e+00  4.697350e-17
# V2  4.697350e-17  1.000000e+00

# %%
creditcard.corr()
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  4.697350e-17 -1.424390e-15  1.755316e-17
# V2     -0.010593  4.697350e-17  1.000000e+00  2.512175e-16 -1.126388e-16
# V3     -0.419618 -1.424390e-15  2.512175e-16  1.000000e+00 -3.416910e-16
# V4     -0.105260  1.755316e-17 -1.126388e-16 -3.416910e-16  1.000000e+00
# V5      0.173072  6.391162e-17 -2.039868e-16 -1.436514e-15 -1.940929e-15
# V6     -0.063016  2.398071e-16  5.024680e-16  1.431581e-15 -2.712659e-16
# V7      0.084714  1.991550e-15  3.966486e-16  2.168574e-15  1.556330e-16
# V8     -0.036949 -9.490675e-17 -4.413984e-17  3.433113e-16  5.195643e-16
# V9     -0.008660  2.169581e-16 -5.728718e-17 -4.233770e-16  3.859585e-16
# V10     0.030617  7.433820e-17 -4.782388e-16  6.289267e-16  6.055490e-16
# V11    -0.247689  2.438580e-16  9.468995e-16 -5.501758e-17 -2.083600e-16
# ...

# %%
df = creditcard.corr()
df1 = df[df>=0.0001]

# %%
df1
# Out:
#             Time        V1        V2   V3        V4        V5        V6  \
# Time    1.000000  0.117396       NaN  NaN       NaN  0.173072       NaN
# V1      0.117396  1.000000       NaN  NaN       NaN       NaN       NaN
# V2           NaN       NaN  1.000000  NaN       NaN       NaN       NaN
# V3           NaN       NaN       NaN  1.0       NaN       NaN       NaN
# V4           NaN       NaN       NaN  NaN  1.000000       NaN       NaN
# V5      0.173072       NaN       NaN  NaN       NaN  1.000000       NaN
# V6           NaN       NaN       NaN  NaN       NaN       NaN  1.000000
# V7      0.084714       NaN       NaN  NaN       NaN       NaN       NaN
# V8           NaN       NaN       NaN  NaN       NaN       NaN       NaN
# V9           NaN       NaN       NaN  NaN       NaN       NaN       NaN
# V10     0.030617       NaN       NaN  NaN       NaN       NaN       NaN
# V11          NaN       NaN       NaN  NaN       NaN       NaN       NaN
# ...

# %%
df1.isnull().sum()
# Out:
# V1        29
# V2        28
# V3        29
# V4        27
# V5        29
# V6        28
# V7        28
# V8        28
# V9        29
# V10       29
# V11       28
# V12       29
# V13       29
# V14       28
# V15       29
# V16       29
# V17       29
# V18       28
# V19       28
# V20       27
# V21       27
# V22       29
# V23       29
# V24       29
# V25       29
# V26       29
# V27       27
# V28       28
# Amount    20
# Class     21
# dtype: int64

# %%
creditcard1 = pd.get_dummies(creditcard, drop_first=True)
print(creditcard1.shape)
creditcard1.head()
# Out:
# (284807, 30)
#             V1        V2        V3        V4        V5        V6        V7  \
# Time
# 0.0  -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 0.0   1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 1.0  -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1.0  -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2.0  -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#             V8        V9       V10  ...         V21       V22       V23  \
# Time                                ...
# 0.0   0.098698  0.363787  0.090794  ...   -0.018307  0.277838 -0.110474
# 0.0   0.085102 -0.255425 -0.166974  ...   -0.225775 -0.638672  0.101288
# 1.0   0.247676 -1.514654  0.207643  ...    0.247998  0.771679  0.909412
# 1.0   0.377436 -1.387024 -0.054952  ...   -0.108300  0.005274 -0.190321
# 2.0  -0.270533  0.817739  0.753074  ...   -0.009431  0.798278 -0.137458
#
# ...

# %%
creditcard1.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15 -1.552563e-15
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01
# max    2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01  3.480167e+01
#
#                  V6            V7            V8            V9           V10  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15  1.768627e-15
# ...

# %%
creditcard.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15 -1.552563e-15
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01
# max    2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01  3.480167e+01
#
#                  V6            V7            V8            V9           V10  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15  1.768627e-15
# ...
